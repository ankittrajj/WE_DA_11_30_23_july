# %%
# analyse the data according to the question.

# 1. try to get atleast 6 the sample of this data.

# 2. find top 10 cars having highest selling price.

# 3. find bottom 1 cars having lowest selling price.

# 4. which owner owns 'Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV' .

# 5. according to selling price of top 10 car tell the transmission of the car.

# 6. tell me the year of the car in which transmission is manual.


df[df['name']== 'toyota']['owner']

x = df['price'].min()
df.head(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8584/4191951018.py in <module>
#      14
#      15
# ---> 16 df[df['name']== 'toyota']['owner']
#      17
#      18 x = df['price'].min()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Satyam\Downloads\Indian Startup.csv')

# %%
df
# Out:
#          Company/Brand  Founded Headquarters  \
# 0         CollegeDekho   2015.0      Gurgaon
# 1                 BOX8   2012.0       Mumbai
# 2                Simpl   2015.0    Bangalore
# 3          8i Ventures   2018.0       Mumbai
# 4            PayGlocal   2021.0    Bangalore
# ...                ...      ...          ...
# 1204          HobSpace   2019.0       Mumbai
# 1205           DcodeAI   2020.0    New Delhi
# 1206  Biocon Biologics   1978.0    Bangalore
# 1207        KiranaKart   2020.0       Mumbai
# 1208             Meddo   2018.0      Gurgaon
#
#                                 Sector  \
# 0                           E-learning
# 1                     Food & Beverages
# 2                    Consumer Services
# 3     Venture Capital & Private Equity
# 4                   Financial Services
# ...                                ...
# 1204                            EdTech
# 1205                            EdTech
# 1206                     BioTechnology
# ...

# %%
# company name,founded==2021,IT sector
df[(df['Founded'] == 2021) & (df['Sector'] == "Information Technology & Services")]['Company/Brand']
# Out:
# 119    The Good Glamm Group
# 187               Hyperface
# 258               Sourcewiz
# 315                EV Plugs
# Name: Company/Brand, dtype: object
