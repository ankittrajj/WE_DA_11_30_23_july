# %%
import matplotlib.pyplot as plt

# %%
# Line plot
# Histogram
# Bar chart
# Pie chart
# Subplot


# Line chart

import numpy as np

# %%
num_of_class = np.array([1,2,3,4,5,6])
num_of_std = np.array([4,3,7,8,9,2])
plt.plot(num_of_class,num_of_std,marker = '.',color = 'red',linestyle = "--")

# %%
#wap to make a graph for temp and days in a city & also try to plot the graph.

days = np.array([1,2,3,4])
temp = np.array([23,34,12,0])
plt.title("temp Graph")
plt.xlabel("Days")
plt.ylabel("Temp")
plt.plot(days,temp)

# %%
# bar chart

sub = ["AI","ML","Python","DB"]
c1 = [5,10,12,14]
c2 = [12,14,20,5]
c3 = [10,18,30,20]

plt.bar(sub,c1)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(sub,c2)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(sub,c3)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(sub,c1,color = 'r')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(sub,c2,color = 'y')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(sub,c3,color = 'g')
# Out:
# <BarContainer object of 4 artists>

# %%
# Which subject have max number of students?

# AI ---> 5,12,10
# ML ----> 10,14,18
# Python ---> 12,20,30
# Db -----> 14,5,20


# Pie chart

population = np.array([32,56,40,89])
mylabels = ['India',"USA",'Canada','UAE']
plt.pie(population,labels = mylabels,colors = ['red','black','Brown','Yellow'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1d684f55490>,
# ...
#  [Text(0.9840524846581532, 0.4915696364078191, 'India'),
#   Text(-0.18229400306357316, 1.084789793668367, 'USA'),
#   Text(-1.0998847245143115, 0.015924596700622313, 'Canada'),
#   Text(0.306431402007073, -1.0564562441786125, 'UAE')])

# %%
#wap to a make a pie chart of gold,silver ,diamond according to different banks
# also try to print the percentage of each category on pie chart.


customer = np.array([89,102,40])
label = ['Gold','Silver','Diamond']
plt.pie(customer,labels = label,colors = ['Yellow','Grey','Red'],autopct ='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d685168dc0>,
# ...
#  [Text(0.3879125568761119, 1.0293317483774789, 'Gold'),
#   Text(-0.8646583907126145, -0.6799749020149727, 'Silver'),
#   Text(0.9412105738422236, -0.5693177106744461, 'Diamond')],
#  [Text(0.2115886673869701, 0.5614536809331703, '38.53'),
#   Text(-0.47163184947960785, -0.370895401099076, '44.16'),
#   Text(0.513387585732122, -0.3105369330951524, '17.32')])

# %%
(89*100)/231
# Out:
# 38.52813852813853

# %%
(40*100)/231
# Out:
# 17.316017316017316

# %%
(102*100)/231
# Out:
# 44.15584415584416

# %%
38.53+17.32+44.16
# Out:
# 100.00999999999999
